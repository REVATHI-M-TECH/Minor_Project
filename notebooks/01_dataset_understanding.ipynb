# %%
import pandas as pd

df = pd.read_csv("../data/raw/lung_cancer_raw.csv")

df.head()
df.info()
df.shape
df.describe()
# Out:
# C:\Users\REVATHI.M\AppData\Local\Temp\ipykernel_7780\411444520.py:3: DtypeWarning: Columns (0: cancer_stage, 1: treatment_type, 2: end_treatment_date) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/lung_cancer_raw.csv")
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1000000 non-null  int64
#  1   age                 1000000 non-null  int64
#  2   gender              1000000 non-null  str
#  3   country             1000000 non-null  str
#  4   diagnosis_date      1000000 non-null  str
#  5   cancer_stage        890000 non-null   str
#  6   family_history      1000000 non-null  str
#  7   smoking_status      1000000 non-null  str
#  8   bmi                 1000000 non-null  float64
#  9   cholesterol_level   1000000 non-null  int64
# ...
